rows x 7 columns]

# %%
# Drop rows with NaT in the 'Date' column
data = data.dropna(subset=['Date'])

# Extract the day of the week from the 'Date' column
data['Day_of_Week'] = data['Date'].dt.day_name()

# Perform one-hot encoding to create dummy variables for each day of the week
data_with_dummies = pd.get_dummies(data, columns=['Day_of_Week'], drop_first=False)

# Check if any of the columns contain boolean values and convert them to integer (0 and 1)
for col in data_with_dummies.columns:
    if data_with_dummies[col].dtype == 'bool':
        data_with_dummies[col] = data_with_dummies[col].astype(int)


# Display the resulting dataframe
data_with_dummies.head()
# Out:
#         Date  Unnamed: 1 Day of the week  PX_LAST    Return  \
# 0 2016-05-09        2019          Monday  2058.69  0.075319
# 1 2016-05-10        2018         Tuesday  2084.39  1.240639
# 2 2016-05-11        2017       Wednesday  2064.46 -0.960756
# 3 2016-05-12        2016        Thursday  2064.11 -0.016955
# 4 2016-05-13        2015          Friday  2046.61 -0.851437
#
#                     Week Day of Week  Day_of_Week_Friday  Day_of_Week_Monday  \
# 0  2016-05-09/2016-05-15      Monday                   0                   1
# 1  2016-05-09/2016-05-15     Tuesday                   0                   0
# 2  2016-05-09/2016-05-15   Wednesday                   0                   0
# 3  2016-05-09/2016-05-15    Thursday                   0                   0
# 4  2016-05-09/2016-05-15      Friday                   1                   0
#
#    Day_of_Week_Thursday  Day_of_Week_Tuesday  Day_of_Week_Wednesday
# 0                     0                    0                      0
# 1                     0                    1                      0
# 2                     0                    0                      1
# 3                     1                    0                      0
# 4                     0                    0                      0

# %%
# Sort by the 'Return' column in descending order
sorted_df = data_with_dummies.sort_values(by='Return', ascending=False)
print(sorted_df.head(10))
# Out:
#            Date  Unnamed: 1 Day of the week  PX_LAST    Return  \
# 831  2020-03-24        1044         Tuesday  2447.33  8.968316
# 824  2020-03-13        1051          Friday  2711.02  8.880836
# 833  2020-03-26        1042        Thursday  2630.07  6.054383
# 826  2020-03-17        1049         Tuesday  2529.19  5.822629
# 1408 2022-11-10         379        Thursday  3956.37  5.395250
# 821  2020-03-10        1054         Tuesday  2882.23  4.821508
# 815  2020-03-02        1060          Monday  3090.23  4.501087
# 817  2020-03-04        1058       Wednesday  3130.12  4.133635
# 835  2020-03-30        1040          Monday  2626.65  3.296662
# 865  2020-05-18        1006          Monday  2953.91  3.101522
#
#                        Week Day of Week  Day_of_Week_Friday  \
# 831   2020-03-23/2020-03-29     Tuesday                   0
# 824   2020-03-09/2020-03-15      Friday                   1
# 833   2020-03-23/2020-03-29    Thursday                   0
# 826   2020-03-16/2020-03-22     Tuesday                   0
# 1408  2022-11-07/2022-11-13    Thursday                   0
# 821   2020-03-09/2020-03-15     Tuesday                   0
# 815   2020-03-02/2020-03-08      Monday                   0
# 817   2020-03-02/2020-03-08   Wednesday                   0
# 835   2020-03-30/2020-04-05      Monday                   0
# 865   2020-05-18/2020-05-24      Monday                   0
#
#       Day_of_Week_Monday  Day_of_Week_Thursday  Day_of_Week_Tuesday  \
# 831                    0                     0                    1
# 824                    0                     0                    0
# 833                    0                     1                    0
# 826                    0                     0                    1
# 1408                   0                     1                    0
# 821                    0                     0                    1
# 815                    1                     0                    0
# 817                    0                     0                    0
# 835                    1                     0                    0
# 865                    1                     0                    0
#
#       Day_of_Week_Wednesday
# 831                       0
# 824                       0
# 833                       0
# 826                       0
# 1408                      0
# 821                       0
# 815                       0
# 817                       1
# 835                       0
# 865                       0

# %%
# Calculating the indices / rows for each

total_rows = len(sorted_df)
top_20_percent_index = int(0.2 * total_rows)
bottom_20_percent_index = int(0.8 * total_rows)

# %%
# Top 20%
top_20_df = sorted_df.head(top_20_percent_index)

# Bottom 20%
bottom_20_df = sorted_df.tail(total_rows - bottom_20_percent_index)

# Middle 60%
middle_60_df = sorted_df.iloc[top_20_percent_index:bottom_20_percent_index]

# %%
# Top 20% Stats

from statsmodels.formula.api import ols
import statsmodels.api as sm

# Define the independent variables (dummy variables for days of the week)
X_6 = top_20_df[['Day_of_Week_Monday', 
                       'Day_of_Week_Thursday', 'Day_of_Week_Tuesday', 
                       'Day_of_Week_Wednesday','Day_of_Week_Friday']]

# Add a constant to the independent variables
# X_6 = sm.add_constant(X_6)

# Define the dependent variable (Returns)
Y_6 = top_20_df['Return']
# Check data types
# print(data_with_dummies.dtypes)

# Create the ANOVA model
ANOVAmodel = ols('Y_6~X_6', data=top_20_df).fit()

# Perform ANOVA
anova_table = sm.stats.anova_lm(ANOVAmodel)

# Print the ANOVA table
print(anova_table)

# Perform OLS regression
model6 = sm.OLS(Y_6, X_6).fit()

# Print the summary of the regression
print(model6.summary())
# Out:
#              df      sum_sq    mean_sq          F        PR(>F)
# X_6         5.0   58.583917  11.716783  13.922265  2.198684e-12
# Residual  339.0  285.297650   0.841586        NaN           NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.051
# Date:                Wed, 19 Jun 2024   Prob (F-statistic):              0.381
# Time:                        11:23:50   Log-Likelihood:                -455.93
# No. Observations:                 344   AIC:                             921.9
# Df Residuals:                     339   BIC:                             941.1
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Day_of_Week_Monday        1.3618      0.114     11.968      0.000       1.138       1.586
# Day_of_Week_Thursday      1.3007      0.107     12.197      0.000       1.091       1.510
# Day_of_Week_Tuesday       1.6035      0.112     14.308      0.000       1.383       1.824
# Day_of_Week_Wednesday     1.4061      0.111     12.639      0.000       1.187       1.625
# Day_of_Week_Friday        1.4169      0.110     12.922      0.000       1.201       1.633
# ==============================================================================
# Omnibus:                      359.176   Durbin-Watson:                   0.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13003.814
# Skew:                           4.559   Prob(JB):                         0.00
# Kurtosis:                      31.707   Cond. No.                         1.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from statsmodels.stats.diagnostic import het_breuschpagan, acorr_breusch_godfrey, het_arch
# Add a constant column to the exog variable
exog_with_constant = sm.add_constant(model6.model.exog)

# Perform the Breusch-Pagan test with the updated exog variable
bp_test = het_breuschpagan(model6.resid, exog_with_constant)
bp_labels = ['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value']
print("Breusch-Pagan test:", dict(zip(bp_labels, bp_test)))

# Breusch-Godfrey test for autocorrelation
bg_test = acorr_breusch_godfrey(model6, nlags=1)
bg_labels = ['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value']
print("Breusch-Godfrey test:", dict(zip(bg_labels, bg_test)))
# Out:
# Breusch-Pagan test: {'Lagrange multiplier statistic': 2.726417174950508, 'p-value': 0.742075177545146, 'f-value': 0.6770634095505355, 'f p-value': 0.6082642268288077}
# Breusch-Godfrey test: {'Lagrange multiplier statistic': 265.7090544391357, 'p-value': 9.775285350585029e-60, 'f-value': 1147.1270369395243, 'f p-value': 1.1265076633594303e-110}

# %%
# Newey-West standard errors - Corrects for autocorrelation
nw_summary = model6.get_robustcov_results(cov_type='HAC', maxlags=1)
print(nw_summary.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 19 Jun 2024   Prob (F-statistic):                nan
# Time:                        11:23:50   Log-Likelihood:                -455.93
# No. Observations:                 344   AIC:                             921.9
# Df Residuals:                     339   BIC:                             941.1
# Df Model:                           4
# Covariance Type:                  HAC
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Day_of_Week_Monday        1.3618      0.088     15.531      0.000       1.189       1.534
# Day_of_Week_Thursday      1.3007      0.101     12.905      0.000       1.102       1.499
# Day_of_Week_Tuesday       1.6035      0.155     10.376      0.000       1.300       1.908
# Day_of_Week_Wednesday     1.4061      0.083     16.960      0.000       1.243       1.569
# Day_of_Week_Friday        1.4169      0.126     11.240      0.000       1.169       1.665
# ==============================================================================
# Omnibus:                      359.176   Durbin-Watson:                   0.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13003.814
# Skew:                           4.559   Prob(JB):                         0.00
# Kurtosis:                      31.707   Cond. No.                         1.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction

# %%
# Middle 60% Stats

import statsmodels.api as sm

# Define the independent variables (dummy variables for days of the week)
X_7 = middle_60_df[['Day_of_Week_Monday', 
                       'Day_of_Week_Thursday', 'Day_of_Week_Tuesday', 
                       'Day_of_Week_Wednesday','Day_of_Week_Friday']]

# Add a constant to the independent variables
# X_7 = sm.add_constant(X_7)

# Define the dependent variable (Returns)
Y_7 = middle_60_df['Return']
# Check data types
# print(data_with_dummies.dtypes)

# Create the ANOVA model
ANOVAmodel = ols('Y_7~X_7', data=middle_60_df).fit()

# Perform ANOVA
anova_table = sm.stats.anova_lm(ANOVAmodel)

# Print the ANOVA table
print(anova_table)

# Perform OLS regression
model7 = sm.OLS(Y_7, X_7).fit()

# Print the summary of the regression
print(model7.summary())
# Out:
#               df      sum_sq   mean_sq         F    PR(>F)
# X_7          5.0    0.849155  0.169831  1.618027  0.152409
# Residual  1027.0  107.795705  0.104962       NaN       NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.5761
# Date:                Wed, 19 Jun 2024   Prob (F-statistic):              0.680
# Time:                        11:23:50   Log-Likelihood:                -298.69
# No. Observations:                1032   AIC:                             607.4
# Df Residuals:                    1027   BIC:                             632.1
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Day_of_Week_Monday        0.1036      0.022      4.744      0.000       0.061       0.146
# Day_of_Week_Thursday      0.0982      0.023      4.267      0.000       0.053       0.143
# Day_of_Week_Tuesday       0.0906      0.023      4.004      0.000       0.046       0.135
# Day_of_Week_Wednesday     0.0612      0.023      2.718      0.007       0.017       0.105
# Day_of_Week_Friday        0.0990      0.023      4.343      0.000       0.054       0.144
# ==============================================================================
# Omnibus:                       81.742   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.286
# Skew:                           0.123   Prob(JB):                     4.37e-07
# Kurtosis:                       2.212   Cond. No.                         1.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from statsmodels.stats.diagnostic import het_breuschpagan, acorr_breusch_godfrey, het_arch
# Add a constant column to the exog variable
exog_with_constant = sm.add_constant(model7.model.exog)

# Perform the Breusch-Pagan test with the updated exog variable
bp_test = het_breuschpagan(model7.resid, exog_with_constant)
bp_labels = ['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value']
print("Breusch-Pagan test:", dict(zip(bp_labels, bp_test)))

# Breusch-Godfrey test for autocorrelation
bg_test = acorr_breusch_godfrey(model7, nlags=1)
bg_labels = ['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value']
print("Breusch-Godfrey test:", dict(zip(bg_labels, bg_test)))
# Out:
# Breusch-Pagan test: {'Lagrange multiplier statistic': 2.3919246874876245, 'p-value': 0.7926760839563293, 'f-value': 0.5964664402287712, 'f p-value': 0.6652641390290384}
# Breusch-Godfrey test: {'Lagrange multiplier statistic': 1025.6025486819976, 'p-value': 4.8894986526568426e-225, 'f-value': 164482.4106729256, 'f p-value': 0.0}

# %%
# Newey-West standard errors - Corrects for autocorrelation
nw_summary = model7.get_robustcov_results(cov_type='HAC', maxlags=1)
print(nw_summary.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 19 Jun 2024   Prob (F-statistic):                nan
# Time:                        11:23:50   Log-Likelihood:                -298.69
# No. Observations:                1032   AIC:                             607.4
# Df Residuals:                    1027   BIC:                             632.1
# Df Model:                           4
# Covariance Type:                  HAC
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Day_of_Week_Monday        0.1036      0.025      4.134      0.000       0.054       0.153
# Day_of_Week_Thursday      0.0982      0.026      3.848      0.000       0.048       0.148
# Day_of_Week_Tuesday       0.0906      0.024      3.713      0.000       0.043       0.138
# Day_of_Week_Wednesday     0.0612      0.024      2.554      0.011       0.014       0.108
# Day_of_Week_Friday        0.0990      0.024      4.123      0.000       0.052       0.146
# ==============================================================================
# Omnibus:                       81.742   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.286
# Skew:                           0.123   Prob(JB):                     4.37e-07
# Kurtosis:                       2.212   Cond. No.                         1.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction

# %%
# Bottom 20% Stats

import statsmodels.api as sm

# Define the independent variables (dummy variables for days of the week)
X_8 = bottom_20_df[['Day_of_Week_Monday', 
                       'Day_of_Week_Thursday', 'Day_of_Week_Tuesday', 
                       'Day_of_Week_Wednesday','Day_of_Week_Friday']]

# Add a constant to the independent variables
# X_8 = sm.add_constant(X_8)

# Define the dependent variable (Returns)
Y_8 = bottom_20_df['Return']
# Check data types
# print(data_with_dummies.dtypes)

# Create the ANOVA model
ANOVAmodel = ols('Y_8~X_8', data=bottom_20_df).fit()

# Perform ANOVA
anova_table = sm.stats.anova_lm(ANOVAmodel)

# Print the ANOVA table
print(anova_table)

# Perform OLS regression
model8 = sm.OLS(Y_8, X_8).fit()

# Print the summary of the regression
print(model8.summary())
# Out:
#              df      sum_sq   mean_sq         F    PR(>F)
# X_8         5.0   10.180144  2.036029  1.300197  0.263319
# Residual  339.0  530.853016  1.565938       NaN       NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.625
# Date:                Wed, 19 Jun 2024   Prob (F-statistic):              0.167
# Time:                        11:23:50   Log-Likelihood:                -562.74
# No. Observations:                 344   AIC:                             1135.
# Df Residuals:                     339   BIC:                             1155.
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Day_of_Week_Monday       -1.7571      0.163    -10.786      0.000      -2.078      -1.437
# Day_of_Week_Thursday     -1.6021      0.147    -10.864      0.000      -1.892      -1.312
# Day_of_Week_Tuesday      -1.2267      0.147     -8.318      0.000      -1.517      -0.937
# Day_of_Week_Wednesday    -1.5105      0.151    -10.027      0.000      -1.807      -1.214
# Day_of_Week_Friday       -1.4553      0.147     -9.868      0.000      -1.745      -1.165
# ==============================================================================
# Omnibus:                      323.321   Durbin-Watson:                   0.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9567.136
# Skew:                          -3.912   Prob(JB):                         0.00
# Kurtosis:                      27.622   Cond. No.                         1.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from statsmodels.stats.diagnostic import het_breuschpagan, acorr_breusch_godfrey, het_arch
# Add a constant column to the exog variable
exog_with_constant = sm.add_constant(model8.model.exog)

# Perform the Breusch-Pagan test with the updated exog variable
bp_test = het_breuschpagan(model8.resid, exog_with_constant)
bp_labels = ['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value']
print("Breusch-Pagan test:", dict(zip(bp_labels, bp_test)))

# Breusch-Godfrey test for autocorrelation
bg_test = acorr_breusch_godfrey(model8, nlags=1)
bg_labels = ['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value']
print("Breusch-Godfrey test:", dict(zip(bg_labels, bg_test)))
# Out:
# Breusch-Pagan test: {'Lagrange multiplier statistic': 6.009327182290511, 'p-value': 0.3053124008993972, 'f-value': 1.5068181451675726, 'f p-value': 0.1997547713452121}
# Breusch-Godfrey test: {'Lagrange multiplier statistic': 329.1282162928682, 'p-value': 1.4882084364888333e-73, 'f-value': 7480.295524580667, 'f p-value': 1.2522178298030797e-232}

# %%
# Newey-West standard errors - Corrects for autocorrelation
nw_summary = model8.get_robustcov_results(cov_type='HAC', maxlags=1)
print(nw_summary.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Return   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 19 Jun 2024   Prob (F-statistic):                nan
# Time:                        11:23:50   Log-Likelihood:                -562.74
# No. Observations:                 344   AIC:                             1135.
# Df Residuals:                     339   BIC:                             1155.
# Df Model:                           4
# Covariance Type:                  HAC
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Day_of_Week_Monday       -1.7571      0.249     -7.063      0.000      -2.247      -1.268
# Day_of_Week_Thursday     -1.6021      0.173     -9.242      0.000      -1.943      -1.261
# Day_of_Week_Tuesday      -1.2267      0.092    -13.265      0.000      -1.409      -1.045
# Day_of_Week_Wednesday    -1.5105      0.145    -10.414      0.000      -1.796      -1.225
# Day_of_Week_Friday       -1.4553      0.123    -11.863      0.000      -1.697      -1.214
# ==============================================================================
# Omnibus:                      323.321   Durbin-Watson:                   0.068
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9567.136
# Skew:                          -3.912   Prob(JB):                         0.00
# Kurtosis:                      27.622   Cond. No.                         1.10
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
